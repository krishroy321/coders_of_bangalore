# %% [markdown]
# *Coders of Bangalore*
#
# You ask Sam Altman for a 2.2 billion USD in funding and he makes fun of you in public
#
# He asks you where you live and finally after talking to you, gives you a challenging task
#
# Collect raw instagram data of all openai followers
#
# Answer these questions:
#
#     - Who has maximum posts
#
#     - who has maximum followers
#
#     - Who follows maximum people
#
#     - How many categories (Digital creators, Non profit foundation etc do we have) of how many people do we have?
#
# You have 24 hours
# You then ask for data - he laughs!

# %% [markdown]
# ******************************************************************************************************************************

# %% [markdown]
# *Data Collection*

# %%
with open ("data.txt",'r',encoding = 'utf-8') as f:
    data = f.read()
data
# Out:
# 'vvvvany_a\nVanya 🖤\n53 posts\n37 followers\n93 following\nNyctophile 🌙\n.\n02~01 💗\n(mine)?\n\nbornebyte\nShubham Shah\n0 posts\n142 followers\n164 following\nForever missing a moment that just passed 📸⌛\n\npriansiillss\npy๋࣭ ^᪲᪲᪲\n5 posts\n299 followers\n169 following\n☆Access to my energy is a privilege🎸\n@kendalljenner\n2211🐲\n\naniket___chandra\nAniket Chandra\n3 posts\n222 followers\n199 following\n💻 Code, Coffee, and Creativity ☕️✨\nKarnataka / Assam\nBengaluru 📍\nJAIN\'29🧑🏻\u200d🎓\n\nanshsharaff_\nAnsh\n2 posts\n45 followers\n47 following\nBlr📍\n\nkrishh_mahato\nᴋʀɪꜱʜ ᴍᴀʜᴀᴛᴏ\n3 posts\n4,371 followers\n774 following\nReel creator\nToo Tired To Deal With Your Bullshytt 🏂\n@karanaujla\n\natharvrastogii._\nAtharv\n0 posts\n432 followers\n390 following\nmy lore is diabolical\n\nbannisa_3066\n𝚑𝚎𝚎𝚛 𝚋𝚑𝚊𝚝𝚒👸\n6 posts\n90 followers\n42 following\n𝙸 𝚖 𝚝𝚑𝚎 𝚕𝚒𝚐𝚑𝚝 𝚒𝚗 𝚖𝚢 𝚘𝚠𝚗 𝚍𝚊𝚛𝚔𝚗𝚎𝚜𝚜\n𝚙𝚛𝚘𝚞𝚍𝚝𝚘𝚋𝚎:𝚛𝚊𝚓𝚎𝚜𝚝𝚑𝚊𝚗𝚒\n𝙶𝚘𝚍\'𝚜 𝚙𝚕𝚊𝚗\n🦚🪞🌷⚜️\n\nr_e_a_l_lvs\nLevistar★⚜🔥\n2 posts\n690 followers\n402 following\n🥷🏽🖤Lone wolf⚕️ The world may be noisy, but the silent man finds peace within🤷🏽\u200d♂️\n\njainconfessions26\n10 posts\n1,063 followers\n1,661 following\nGossips Matchmaking Confessions\nFollow Us To Unite And Have Some Tea Here\nof Our college 😛😛\nngl.link/confessionpo\n\nworstyear2026\nHappy\n0 posts\n2,771 followers\n1,864 following\n\ndoramon__old\ndoramon\n0 posts\n0 followers\n50 following\n\nrecord_notes_jainuniversity\nWriting notes\n14 posts\n4,144 followers\n3,126 following\nWriting Service\nWe Write Ur Notes 📝 | Custom notes that save your time |Crafting PPTs, Word,Reports |DM for orders |\n\nmspg1502\nMS ℙ𝔸𝕐𝕀ℕ𝔾 𝔾𝕌𝔼𝕊𝕋\n157 posts\n611 followers\n5,324 following\nHostel\n𝗡𝗘𝗔𝗥 𝗗𝗔𝗬𝗔𝗡𝗔𝗡𝗗𝗔 𝗦𝗔𝗚𝗔𝗥 𝗨𝗡𝗜𝗩𝗘𝗥𝗦𝗜𝗧𝗬 𝗔𝗡𝗗\n𝗝𝗔𝗜𝗡 𝗨𝗡𝗜𝗩𝗘𝗥𝗦𝗜𝗧𝗬 💫\ncontacts : 8971650368 / 9731022414\nmaps.app.goo.gl/9wdatsJc83i4HN5h9\n\nswapnil_ghosh__\nSwapnil Ghosh\n48 posts\n187 followers\n209 following\n\nnamratha_gowda1999\n0 posts\n122 followers\n142 following\n\nananya___mondal_\nঅ ন ন্যা🍷\n40 posts\n167 followers\n50 following\n🚩\ntuli..🧿🖤\n__Life is a book with every chapter\nteaching something new.\n\nkhushi_bishal_\nkhushi_bishal_♓️\n290 posts\n1,049 followers\n452 following\n🌸 Be real. Stay kind. Grow strong.\nfeb 19 ♓️\n27/05 🌻\n\n\njain_underground\nJain Underground\n53 posts\n383 followers\n474 following\nThe unofficial voice of Jain 💬\nConfessions. Chaos. Red flags. Secrets\nWelcome to the Underground 🔥\n\nm_living_dead\nshreet panda...\n22 posts\n449 followers\n742 following\nArtist\nlife is all about moving onnn...\nSatisfied for now... More to come!\n\nblidee2024\n0 posts\n0 followers\n68 following\n\n_nxthrx_.04_\nℕ𝕖𝕥𝕙𝕣𝕒🖤\n0 posts\n918 followers\n1,194 following\n~JU\'29🎓\n.\n.\n.\n.\n~@_.poovi._08_ 🤍🧿\n~close your eyes face the sun smile🤍☄️🎀\n\n_nxthrx_.04_\nℕ𝕖𝕥𝕙𝕣𝕒🖤\n0 posts\n918 followers\n1,194 following\n~JU\'29🎓\n.\n.\n.\n.\n~@_.poovi._08_ 🤍🧿\n~close your eyes face the sun smile🤍☄️🎀\n\njain_confession77\nJain College Jayanagar confession\n55 posts\n1,111 followers\n911 following\n“GPA? Nah. Gossip Per Annum — we got that covered.”😮\u200d💨☠️\nconfess.ngl.link/confessyourheartout18489\n\ncoder4gamer4passion\nʞɘʜꙅiʜdA\n1 post\n68 followers\n203 following\n꧁༒♛𝔄𝔟𝔥𝔦𝔰𝔥𝔢𝔨♛༒꧂\n\n\nyuvr_ajsingh._.0019\n🖤Yuvraj Singh\U0001fa76\n17 posts\n722 followers\n381 following\nEunoia 🌸\n\nsoumilpanda\n1 post\n36 followers\n99 following\n\nalok4537singh\nAlok kumar singh\n1 post\n122 followers\n185 following\nZindagi Gulzar Hai\nJU || Blr\n\ndearnitya\nnitya ꩜\nshe\n0 posts\n815 followers\n700 following\n୨୧ 🌺\n@radvxz\npin.it/5M4RkFNxG\n\namanchand_20\nAman Chand\n1 post\n114 followers\n108 following\n\n__anmol_11\nAnmol Regmi\n20 posts\n343 followers\n245 following\nDon\'t follow me... Cause I don\'t know where I am going😎💀\n\ndsclassof29\nClass of 29\n2 posts\n38 followers\n39 following\nPolaroids today, flames tomorrow\n#29crew\n\njwaline_\njwaline\nhe\n21 posts\n4,138 followers\n1,762 following\nActor\nKL 📍Bgrl\nDo something new.\nPhase of expansion.\n\ndaksh__kapoor__19\ ...

# %%
chunks = data.split("\n\n")
chunks = [c for c in chunks if len(c)>3]

# %%
def parse_chunk(chunk):
    try:
        chunk = chunk.strip()
        sep_chunk = chunk.split("\n")
        username = sep_chunk[0] if len(sep_chunk) > 0 else ""
        name = sep_chunk[1] if len(sep_chunk) > 1 else ""
        no_of_posts = sep_chunk[2] if len(sep_chunk) > 2 else ""
        no_of_followers = sep_chunk[3]  if len(sep_chunk) > 3 else ""
        no_of_following = sep_chunk[4] if len(sep_chunk) > 4 else ""
        if len(sep_chunk)>5:
            type_of_page = sep_chunk[5]
            bio = "\n".join(sep_chunk[6:])
        else:
            type_of_page = "Unknown"
            bio = ""
        return {"Username": username, 
                "Name":name,
                "No of Post":no_of_posts,
                "No of Followers":no_of_followers,
                "No of Following ":no_of_following,
                "Type Of Page ":type_of_page,
                "Bio ":bio}
    except Exception as e:
        print("Error:",e)
        print(chunk)

# %%
parse_chunk(chunks[1])
# Out:
# {'Username': 'bornebyte',
#  'Name': 'Shubham Shah',
#  'No of Post': '0 posts',
#  'No of Followers': '142 followers',
#  'No of Following ': '164 following',
#  'Type Of Page ': 'Forever missing a moment that just passed 📸⌛',
#  'Bio ': ''}

# %%
all_chunks = []
for chunk in chunks:
    all_chunks.append(parse_chunk(chunk))
print(all_chunks[0])
# Out:
# {'Username': 'vvvvany_a', 'Name': 'Vanya 🖤', 'No of Post': '53 posts', 'No of Followers': '37 followers', 'No of Following ': '93 following', 'Type Of Page ': 'Nyctophile 🌙', 'Bio ': '.\n02~01 💗\n(mine)?'}

# %%
import json
s = json.dumps(all_chunks,indent=4,ensure_ascii=False)
print(s)
# Out:
# [
#     {
#         "Username": "vvvvany_a",
#         "Name": "Vanya 🖤",
#         "No of Post": "53 posts",
#         "No of Followers": "37 followers",
#         "No of Following ": "93 following",
#         "Type Of Page ": "Nyctophile 🌙",
#         "Bio ": ".\n02~01 💗\n(mine)?"
#     },
#     {
#         "Username": "bornebyte",
#         "Name": "Shubham Shah",
#         "No of Post": "0 posts",
#         "No of Followers": "142 followers",
#         "No of Following ": "164 following",
#         "Type Of Page ": "Forever missing a moment that just passed 📸⌛",
#         "Bio ": ""
#     },
#     {
#         "Username": "priansiillss",
#         "Name": "py๋࣭ ^᪲᪲᪲",
#         "No of Post": "5 posts",
#         "No of Followers": "299 followers",
#         "No of Following ": "169 following",
#         "Type Of Page ": "☆Access to my energy is a privilege🎸",
#         "Bio ": "@kendalljenner\n2211🐲"
#     },
#     {
#         "Username": "aniket___chandra",
#         "Name": "Aniket Chandra",
#         "No of Post": "3 posts",
#         "No of Followers": "222 followers",
#         "No of Following ": "199 following",
#         "Type Of Page ": "💻 Code, Coffee, and Creativity ☕️✨",
#         "Bio ": "Karnataka / Assam\nBengaluru 📍\nJAIN'29🧑🏻‍🎓"
#     },
#     {
#         "Username": "anshsharaff_",
#         "Name": "Ansh",
#         "No of Post": "2 posts",
#         "No of Followers": "45 followers",
#         "No of Following ": "47 following",
#         "Type Of Page ": "Blr📍",
#         "Bio ": ""
#     },
#     {
#         "Username": "krishh_mahato",
#         "Name": "ᴋʀɪꜱʜ ᴍᴀʜᴀᴛᴏ",
#         "No of Post": "3 posts",
#         "No of Followers": "4,371 followers",
#         "No of Following ": "774 following",
#         "Type Of Page ": "Reel creator",
#         "Bio ": "Too Tired To Deal With Your Bullshytt 🏂\n@karanaujla"
#     },
#     {
#         "Username": "atharvrastogii._",
#         "Name": "Atharv",
#         "No of Post": "0 posts",
#         "No of Followers": "432 followers",
#         "No of Following ": "390 following",
#         "Type Of Page ": "my lore is diabolical",
#         "Bio ": ""
#     },
#     {
#         "Username": "bannisa_3066",
#         "Name": "𝚑𝚎𝚎𝚛 𝚋𝚑𝚊𝚝𝚒👸",
#         "No of Post": "6 posts",
#         "No of Followers": "90 followers",
#         "No of Following ": "42 following",
#         "Type Of Page ": "𝙸 𝚖 𝚝𝚑𝚎 𝚕𝚒𝚐𝚑𝚝 𝚒𝚗 𝚖𝚢 𝚘𝚠𝚗 𝚍𝚊𝚛𝚔𝚗𝚎𝚜𝚜",
#         "Bio ": "𝚙𝚛𝚘𝚞𝚍𝚝𝚘𝚋𝚎:𝚛𝚊𝚓𝚎𝚜𝚝𝚑𝚊𝚗𝚒\n𝙶𝚘𝚍'𝚜 𝚙𝚕𝚊𝚗\n🦚🪞🌷⚜️"
#     },
#     {
#         "Username": "r_e_a_l_lvs",
#         "Name": "Levistar★⚜🔥",
#         "No of Post": "2 posts",
#         "No of Followers": "690 followers",
#         "No of Following ": "402 following",
#         "Type Of Page ": "🥷🏽🖤Lone wolf⚕️ The world may be noisy, but the silent man finds peace within🤷🏽‍♂️",
#         "Bio ": ""
#     },
#     {
#         "Username": "jainconfessions26",
#         "Name": "10 posts",
#         "No of Post": "1,063 followers",
#         "No of Followers": "1,661 following",
#         "No of Following ": "Gossips Matchmaking Confessions",
#         "Type Of Page ": "Follow Us To Unite And Have Some Tea Here",
#         "Bio ": "of Our college 😛😛\nngl.link/confessionpo"
#     },
#     {
#         "Username": "worstyear2026",
#         "Name": "Happy",
#         "No of Post": "0 posts",
#         "No of Followers": "2,771 followers",
#         "No of Following ": "1,864 following",
#         "Type Of Page ": "Unknown",
#         "Bio ": ""
#     },
#     {
#         "Username": "doramon__old",
#         "Name": "doramon",
#         "No of Post": "0 posts",
#         "No of Followers": "0 followers",
#         "No of Following ": "50 following",
#         "Type Of Page ": "Unknown",
#         "Bio ": ""
#     },
#     {
#         "Username": "record_notes_jainuniversity",
#         "Name": "Writing notes",
#         "No of Post": "14 posts",
#         "No of Followers": "4,144 followers",
#         "No of Following ": "3,126 following",
#         "Type Of Page ": "Writing Service",
#         "Bio ": "We Write Ur Notes 📝 | Custom notes that save your time |Crafting PPTs, Word,Reports |DM for orders |"
#     },
#     {
#         "Username": "mspg1502",
#         "Name": "MS ℙ𝔸𝕐𝕀ℕ𝔾 𝔾𝕌𝔼𝕊𝕋",
#         "No of Post": "157 posts",
#         "No of Followers": "611 followers",
#         "No of Following ": "5,324 following",
#         "Type Of Page ": "Hostel",
#         "Bio ": "𝗡𝗘𝗔𝗥 𝗗𝗔𝗬𝗔𝗡𝗔𝗡𝗗𝗔 𝗦𝗔𝗚𝗔𝗥 𝗨𝗡𝗜𝗩𝗘𝗥𝗦𝗜𝗧𝗬 𝗔𝗡𝗗\n𝗝𝗔𝗜𝗡 𝗨𝗡𝗜𝗩𝗘𝗥𝗦𝗜𝗧𝗬 💫\ncontacts : 8971650368 / 9731022414\nmaps.app.goo.gl/9wdatsJc83i4HN5h9"
#     },
#     {
#         "Username": "swapnil_ghosh__",
#         "Name": "Swapnil Ghosh",
#         "No of Post": "48 posts",
#         "No of Followers": "187 followers",
#         "No of Following ": "209 following",
#         "Type Of Page ": "Unknown",
#         "Bio ": ""
#     },
#     {
#         "Username": "namratha_gowda1999",
#         "Name": "0 posts",
#         "No of Post": "122 followers",
#         "No of Followers": "142 following",
#         "No of Following ": "",
#         "Type Of Page ": "Unknown",
#         "Bio ": ""
#     },
#     {
#         "Username": "ananya___mondal_",
#         "Name": "অ ন ন্যা🍷",
#         "No of Post": "40 posts",
#         "No of Followers": "167 followers",
#         "No of Following ": "50 following",
#         "Type Of Page ": "🚩",
#         "Bio ": "tuli..🧿🖤\n__Life is a book with every chapter\nteaching something new."
#     },
#     {
#         "Username": "khushi_bishal_",
#         "Name": "khushi_bishal_♓️",
#         "No of Post": "290 posts",
#         "No of Followers": "1,049 followers",
#         "No of Following ": "452 following",
#         "Type Of Page ": "🌸 Be real. Stay kind. Grow strong.",
#         "Bio ": "feb 19 ♓️\n27/05 🌻"
#     },
#     {
#         "Username": "jain_underground",
#         "Name": "Jain Underground",
#         "No of Post": "53 posts",
#         "No of Followers": "383 followers",
#         "No of Following ": "474 following",
#         "Type Of Page ": "The unofficial voice of Jain 💬",
#         "Bio ": "Confessions. Chaos. Red flags. Secrets\nWelcome to the Underground 🔥"
#     },
#     {
#         "Username": "m_living_dead",
#         "Name": "shreet panda...",
#         "No of Post": "22 posts",
#         "No of Followers": "449 followers",
#         "No of Following ": "742 following",
#         "Type Of Page ": "Artist",
#         "Bio ": "life is all about moving onnn...\nSatisfied for now... More to come!"
#     },
#     {
#         "Username": "blidee2024",
#         "Name": "0 posts",
#         "No of Post": "0 followers",
#         "No of Followers": "68 following",
#         "No of Following ": "",
#         "Type Of Page ": "Unknown",
#         "Bio ": ""
#     },
#     {
#         "Username": "_nxthrx_.04_",
#         "Name": "ℕ𝕖𝕥𝕙𝕣𝕒🖤",
#         "No of Post": "0 posts",
#         "No of Followers": "918 followers",
#         "No of Following ": "1,194 following",
#         "Type Of Page ": "~JU'29🎓",
#         "Bio ": ".\n.\n.\n.\n~@_.poovi._08_ 🤍🧿\n~close your eyes face the sun smile🤍☄️🎀"
#     },
#     {
#         "Username": "_nxthrx_.04_",
#         "Name": "ℕ𝕖𝕥𝕙𝕣𝕒🖤",
#         "No of Post": "0 posts",
#         "No of Followers": "918 followers",
#         "No of Following ": "1,194 following",
#         "Type Of Page ": "~JU'29🎓",
#         "Bio ": ".\n.\n.\n.\n~@_.poovi._08_ 🤍🧿\n~close your eyes face the sun smile🤍☄️🎀"
#     },
#     {
#         "Username": "jain_confession77",
#         "Name": "Jain College Jayanagar confession",
#         "No of Post": "55 posts",
#         "No of Followers": "1,111 followers",
#         "No of Following ": "911 following",
#         "Type Of Page ": "“GPA? Nah. Gossip Per Annum — we got that covered.”😮‍💨☠️",
#         "Bio ": "confess.ngl.link/confessyourheartout18489"
#     },
#     {
#         "Username": "coder4gamer4passion",
#         "Name": "ʞɘʜꙅiʜdA",
#         "No of Post": "1 post",
#         "No of Followers": "68 followers",
#         "No of Following ": "203 following",
#         "Type Of Page ": "꧁༒♛𝔄𝔟𝔥𝔦𝔰𝔥𝔢𝔨♛༒꧂",
#         "Bio ": ""
#     },
#     {
#         "Username": "yuvr_ajsingh._.0019",
#         "Name": "🖤Yuvraj Singh🩶",
#         "No of Post": "17 posts",
#         "No of Followers": "722 followers",
#         "No of Following ": "381 following",
#         "Type Of Page ": "Eunoia 🌸",
#         "Bio ": ""
#     },
#     {
#         "Username": "soumilpanda",
#         "Name": "1 post",
#         "No of Post": "36 followers",
#         "No of Followers": "99 following",
#         "No of Following ": "",
#         "Type Of Page ": "Unknown",
#         "Bio ": ""
#     },
#     {
#         "Username": "alok4537singh",
#         "Name": "Alok kumar singh",
#         "No of Post": "1 post",
#         "No of Followers": "122 followers",
#         "No of Following ": "185 following",
#         "Type Of Page ": "Zindagi Gulzar Hai",
#         "Bio ": "JU || Blr"
#     },
#     {
#         "Username": "dearnitya",
#         "Name": "nitya ꩜",
#         "No of Post": "she",
#         "No of Followers": "0 posts",
#         "No of Following ": "815 followers",
#         "Type Of Page ": "700 following",
#         "Bio ": "୨୧ 🌺\n@radvxz\npin.it/5M4RkFNxG"
#     },
#     {
#         "Username": "amanchand_20",
#         "Name": "Aman Chand",
#         "No of Post": "1 post",
#         "No of Followers": "114 followers",
#         "No of Following ": "108 following",
#         "Type Of Page ": "Unknown",
#         "Bio ": ""
#     },
#     {
#         "Username": "__anmol_11",
#         "Name": "Anmol Regmi",
#         "No of Post": "20 posts",
#         "No of Followers": "343 followers",
#         "No of Following ": "245 following",
#         "Type Of Page ": "Don't follow me... Cause I don't know where I am going😎💀",
#         "Bio ": ""
#     },
#     {
#         "Username": "dsclassof29",
#         "Name": "Class of 29",
#         "No of Post": "2 posts",
#         "No of Followers": "38 followers",
#         "No of Following ": "39 following",
#         "Type Of Page ": "Polaroids today, flames tomorrow",
#         "Bio ": "#29crew"
#     },
#     {
#         "Username": "jwaline_",
#         "Name": "jwaline",
#         "No of Post": "he",
#         "No of Followers": "21 posts",
#         "No of Following ": "4,138 followers",
#         "Type Of Page ": "1,762 following",
#         "Bio ": "Actor\nKL 📍Bgrl\nDo something new.\nPhase of expansion."
#     },
#     {
#         "Username": "daksh__kapoor__19",
#         "Name": "0 posts",
#         "No of Post": "101 followers",
#         "No of Followers": "124 following",
#         "No of Following ": "",
#         "Type Of Page ": "Unknown",
#         "Bio ": ""
#     },
#     {
#         "Username": "souravvv_20",
#         "Name": "𝙎𝙊𝙐𝙍𝘼𝙑",
#         "No of Post": "1 post",
#         "No of Followers": "331 followers",
#         "No of Following ": "236 following",
#         "Type Of Page ": "📍Bengaluru",
#         "Bio ": ""
#     },
#     {
#         "Username": "_aromalsuresh_",
#         "Name": "aro",
#         "No of Post": "0 posts",
#         "No of Followers": "1,637 followers",
#         "No of Following ": "1,539 following",
#         "Type Of Page ": "Patience.",
#         "Bio ": ""
#     },
#     {
#         "Username": "_.akshay.ps._",
#         "Name": "aks_hay_89",
#         "No of Post": "3 posts",
#         "No of Followers": "1,218 followers",
#         "No of Following ": "977 following",
#         "Type Of Page ": "Personal blog",
#         "Bio ": "ernakulam 📍bangalore"
#     },
#     {
#         "Username": "senthil7379",
#         "Name": "senthil kumar",
#         "No of Post": "4 posts",
#         "No of Followers": "41 followers",
#         "No of Following ": "73 following",
#         "Type Of Page ": "Unknown",
#         "Bio ": ""
#     },
#     {
#         "Username": "aditiya_sahrawat09",
#         "Name": "Aditiya",
#         "No of Post": "0 posts",
#         "No of Followers": "247 followers",
#         "No of Following ": "324 following",
#         "Type Of Page ": "yearning",
#         "Bio ": ""
#     },
#     {
#         "Username": "adithyaa_31",
#         "Name": "Adiii🖤",
#         "No of Post": "4 posts",
#         "No of Followers": "906 followers",
#         "No of Following ": "932 following",
#         "Type Of Page ": "\"𝓡𝓪𝓭𝓱𝓮 𝓴𝓻𝓲𝓼𝓱𝓷𝓪\"",
#         "Bio ": "𝑯𝒂𝒍𝒇 𝒄𝒐𝒇𝒇𝒆𝒆, 𝒉𝒂𝒍𝒇 𝒂𝒎𝒃𝒊𝒕𝒊𝒐𝒏"
#     },
#     {
#         "Username": "4ppl_ju1ce",
#         "Name": "evicka.png",
#         "No of Post": "15 posts",
#         "No of Followers": "269 followers",
#         "No of Following ": "1,026 following",
#         "Type Of Page ": "🤍🦌🐇🩰",
#         "Bio ": "@h4n1kk\n.\n.\n.\n.\n.\n.\n."
#     },
#     {
#         "Username": "ansh_sharaff",
#         "Name": "Ānsh Sharaff",
#         "No of Post": "33 posts",
#         "No of Followers": "139 followers",
#         "No of Following ": "194 following",
#         "Type Of Page ": "radhe radhe❤️❤️",
#         "Bio ": ""
#     },
#     {
#         "Username": "adhikarigaurabh",
#         "Name": "G A U R A B H",
#         "No of Post": "7 posts",
#         "No of Followers": "429 followers",
#         "No of Following ": "376 following",
#         "Type Of Page ": "Euphoric",
#         "Bio ": ""
#     },
#     {
#         "Username": "raunak_sarraf__",
#         "Name": "Raunak sarraf",
#         "No of Post": "0 posts",
#         "No of Followers": "193 followers",
#         "No of Following ": "220 following",
#         "Type Of Page ": "JU' 29(maybe 30, worst case scenario 31)",
#         "Bio ": "So Far, So good🍃"
#     },
#     {
#         "Username": "hareshhhh.h",
#         "Name": "𝙃𝘼𝙍𝙀𝙎𝙃",
#         "No of Post": "5 posts",
#         "No of Followers": "1,016 followers",
#         "No of Following ": "1,034 following",
#         "Type Of Page ": "just documenting the life 📽",
#         "Bio ": ""
#     },
#     {
#         "Username": "wishallllllltejas",
#         "Name": "Vishal Tejas",
#         "No of Post": "5 posts",
#         "No of Followers": "326 followers",
#         "No of Following ": "309 following",
#         "Type Of Page ": "Dolce far niente",
#         "Bio ": "@the.cforge Content Creator 😎"
#     },
#     {
#         "Username": "pranish_k7",
#         "Name": "Pranish Karki",
#         "No of Post": "0 posts",
#         "No of Followers": "179 followers",
#         "No of Following ": "226 following",
#         "Type Of Page ": "Just try it",
#         "Bio ": ""
#     }
# ]
