# %% [markdown]
# *Coders of Bangalore*
#
# You ask Sam Altman for a 2.2 billion USD in funding and he makes fun of you in public
#
# He asks you where you live and finally after talking to you, gives you a challenging task
#
# Collect raw instagram data of all openai followers
#
# Answer these questions:
#
#     - Who has maximum posts
#
#     - who has maximum followers
#
#     - Who follows maximum people
#
#     - How many categories (Digital creators, Non profit foundation etc do we have) of how many people do we have?
#
# You have 24 hours
# You then ask for data - he laughs!

# %% [markdown]
# ******************************************************************************************************************************

# %% [markdown]
# *Data Collection*

# %%
with open ("data.txt",'r',encoding = 'utf-8') as f:
    data = f.read()

# %%
chunks = data.split("\n\n")
chunks = [c for c in chunks if len(c)>3]

# %%
def parse_chunk(chunk):
    try:
        chunk = chunk.strip()
        sep_chunk = chunk.split("\n")
        username = sep_chunk[0] if len(sep_chunk) > 0 else "" 
        name = sep_chunk[1] if len(sep_chunk) > 1 else ""
        no_of_posts = int(sep_chunk[2].split(" post")[0].replace(",",""))if len(sep_chunk) > 2 else ""
        no_of_followers = int(sep_chunk[3].split(" follower")[0].replace(",",""))if len(sep_chunk) > 3 else ""
        no_of_following = int(sep_chunk[4].split(" following")[0].replace(",",""))if len(sep_chunk) > 4 else ""
        if len(sep_chunk)>5:
            type_of_page = sep_chunk[5]
            bio = "\n".join(sep_chunk[6:])
        else:
            type_of_page = "Unknown"
            bio = ""
        return {"Username": username, 
                "Name":name,
                "No of Post":no_of_posts,
                "No of Followers":no_of_followers,
                "No of Following ":no_of_following,
                "Type Of Page ":type_of_page,
                "Bio ":bio}
    except Exception as e:
        print("Error:",e)
        print(chunk)

# %%
parse_chunk(chunks[50])
# Out:
# Error: invalid literal for int() with base 10: '1.1M'
# karanaujlaglobal
# TEAM AUJLA
# 421 posts
# 1.1M followers
# 4 following
# Team @karanaujla
# Bookings, Partnerships & Inquiries - info@kammm.in

# %%
all_chunks = []
for chunk in chunks:
    all_chunks.append(parse_chunk(chunk))
print(all_chunks[0])
# Out:
# Error: invalid literal for int() with base 10: '1.2M'
# nidarehmannn
# Nida Rehman
# 512 posts
# 1.2M followers
# 15 following
# aik dum bindas 🐣
# mgmt: @saadahmedbhatti @juggernautmediapr
# Error: invalid literal for int() with base 10: '258K'
# prepartitionboys
# PrePartition Boys
# 449 posts
# 258K followers
# 6 following
# dc | nyc
# 📧: prepartitionboys@gmail.com
# YT: Pre-partitionboys
# youtube.com/@pre-partitionboys?si=og556CAeKraiz0FG
# Error: invalid literal for int() with base 10: '250K'
# kshitijsharma.ig
# Kshitij Sharma
# 224 posts
# 250K followers
# 1,164 following
# Digital creator
# 📍NYC | @illinois1867 alum
# 📨 kshitij@friendsinreality.com
# Error: invalid literal for int() with base 10: '9.7M'
# maisamayhoon
# Samay Raina
# 439 posts
# 9.7M followers
# 3 following
# Comedian
# For business: contact@samayraina.co
# linktr.ee/samayrainaa
# Error: invalid literal for int() with base 10: '26.6M'
# diljitdosanjh
# DILJIT DOSANJH
# 722 posts
# 26.6M followers
# 0 following
# AURA WORLD TOUR 2026 🇨🇦 🇺🇸
# www.ticketmaster.com/diljit-dosanjh-tickets/artist/2108512
# Error: invalid literal for int() with base 10: '105K'
# avibainz
# Avi
# 109 posts
# 105K followers
# 5 following
# Entrepreneur
# 444
# WMK
# Error: invalid literal for int() with base 10: '291K'
# kaushik____devansh
# Devansh kaushik
# 388 posts
# 291K followers
# 721 following
# Life is good
# bogsila.com
# Error: invalid literal for int() with base 10: '13.8M'
# karanaujla
# Karan Aujla
# 228 posts
# 13.8M followers
# 841 following
# Artist
# @stake Code - AUJLA
# Error: invalid literal for int() with base 10: '1.1M'
# karanaujlaglobal
# TEAM AUJLA
# 421 posts
# 1.1M followers
# 4 following
# Team @karanaujla
# Bookings, Partnerships & Inquiries - info@kammm.in
# {'Username': 'vvvvany_a', 'Name': 'Vanya 🖤', 'No of Post': 53, 'No of Followers': 37, 'No of Following ': 93, 'Type Of Page ': 'Nyctophile 🌙', 'Bio ': '.\n02~01 💗\n(mine)?'}

# %%
import json
s = json.dumps(all_chunks,indent=4,ensure_ascii=False)
print(s)
# Out:
# [
#     {
#         "Username": "vvvvany_a",
#         "Name": "Vanya 🖤",
#         "No of Post": 53,
#         "No of Followers": 37,
#         "No of Following ": 93,
#         "Type Of Page ": "Nyctophile 🌙",
#         "Bio ": ".\n02~01 💗\n(mine)?"
#     },
#     {
#         "Username": "bornebyte",
#         "Name": "Shubham Shah",
#         "No of Post": 0,
#         "No of Followers": 142,
#         "No of Following ": 164,
#         "Type Of Page ": "Forever missing a moment that just passed 📸⌛",
#         "Bio ": ""
#     },
#     {
#         "Username": "priansiillss",
#         "Name": "py๋࣭ ^᪲᪲᪲",
#         "No of Post": 5,
#         "No of Followers": 299,
#         "No of Following ": 169,
#         "Type Of Page ": "☆Access to my energy is a privilege🎸",
#         "Bio ": "@kendalljenner\n2211🐲"
#     },
#     {
#         "Username": "aniket___chandra",
#         "Name": "Aniket Chandra",
#         "No of Post": 3,
#         "No of Followers": 222,
#         "No of Following ": 199,
#         "Type Of Page ": "💻 Code, Coffee, and Creativity ☕️✨",
#         "Bio ": "Karnataka / Assam\nBengaluru 📍\nJAIN'29🧑🏻‍🎓"
#     },
#     {
#         "Username": "anshsharaff_",
#         "Name": "Ansh",
#         "No of Post": 2,
#         "No of Followers": 45,
#         "No of Following ": 47,
#         "Type Of Page ": "Blr📍",
#         "Bio ": ""
#     },
#     {
#         "Username": "krishh_mahato",
#         "Name": "ᴋʀɪꜱʜ ᴍᴀʜᴀᴛᴏ",
#         "No of Post": 3,
#         "No of Followers": 4371,
#         "No of Following ": 774,
#         "Type Of Page ": "Reel creator",
#         "Bio ": "Too Tired To Deal With Your Bullshytt 🏂\n@karanaujla"
#     },
#     {
#         "Username": "atharvrastogii._",
#         "Name": "Atharv",
#         "No of Post": 0,
#         "No of Followers": 432,
#         "No of Following ": 390,
#         "Type Of Page ": "my lore is diabolical",
#         "Bio ": ""
#     },
#     {
#         "Username": "bannisa_3066",
#         "Name": "𝚑𝚎𝚎𝚛 𝚋𝚑𝚊𝚝𝚒👸",
#         "No of Post": 6,
#         "No of Followers": 90,
#         "No of Following ": 42,
#         "Type Of Page ": "𝙸 𝚖 𝚝𝚑𝚎 𝚕𝚒𝚐𝚑𝚝 𝚒𝚗 𝚖𝚢 𝚘𝚠𝚗 𝚍𝚊𝚛𝚔𝚗𝚎𝚜𝚜",
#         "Bio ": "𝚙𝚛𝚘𝚞𝚍𝚝𝚘𝚋𝚎:𝚛𝚊𝚓𝚎𝚜𝚝𝚑𝚊𝚗𝚒\n𝙶𝚘𝚍'𝚜 𝚙𝚕𝚊𝚗\n🦚🪞🌷⚜️"
#     },
#     {
#         "Username": "r_e_a_l_lvs",
#         "Name": "Levistar★⚜🔥",
#         "No of Post": 2,
#         "No of Followers": 690,
#         "No of Following ": 402,
#         "Type Of Page ": "🥷🏽🖤Lone wolf⚕️ The world may be noisy, but the silent man finds peace within🤷🏽‍♂️",
#         "Bio ": ""
#     },
#     {
#         "Username": "worstyear2026",
#         "Name": "Happy",
#         "No of Post": 0,
#         "No of Followers": 2771,
#         "No of Following ": 1864,
#         "Type Of Page ": "Unknown",
#         "Bio ": ""
#     },
#     {
#         "Username": "doramon__old",
#         "Name": "doramon",
#         "No of Post": 0,
#         "No of Followers": 0,
#         "No of Following ": 50,
#         "Type Of Page ": "Unknown",
#         "Bio ": ""
#     },
#     {
#         "Username": "record_notes_jainuniversity",
#         "Name": "Writing notes",
#         "No of Post": 14,
#         "No of Followers": 4144,
#         "No of Following ": 3126,
#         "Type Of Page ": "Writing Service",
#         "Bio ": "We Write Ur Notes 📝 | Custom notes that save your time |Crafting PPTs, Word,Reports |DM for orders |"
#     },
#     {
#         "Username": "mspg1502",
#         "Name": "MS ℙ𝔸𝕐𝕀ℕ𝔾 𝔾𝕌𝔼𝕊𝕋",
#         "No of Post": 157,
#         "No of Followers": 611,
#         "No of Following ": 5324,
#         "Type Of Page ": "Hostel",
#         "Bio ": "𝗡𝗘𝗔𝗥 𝗗𝗔𝗬𝗔𝗡𝗔𝗡𝗗𝗔 𝗦𝗔𝗚𝗔𝗥 𝗨𝗡𝗜𝗩𝗘𝗥𝗦𝗜𝗧𝗬 𝗔𝗡𝗗\n𝗝𝗔𝗜𝗡 𝗨𝗡𝗜𝗩𝗘𝗥𝗦𝗜𝗧𝗬 💫\ncontacts : 8971650368 / 9731022414\nmaps.app.goo.gl/9wdatsJc83i4HN5h9"
#     },
#     {
#         "Username": "swapnil_ghosh__",
#         "Name": "Swapnil Ghosh",
#         "No of Post": 48,
#         "No of Followers": 187,
#         "No of Following ": 209,
#         "Type Of Page ": "Unknown",
#         "Bio ": ""
#     },
#     {
#         "Username": "ananya___mondal_",
#         "Name": "অ ন ন্যা🍷",
#         "No of Post": 40,
#         "No of Followers": 167,
#         "No of Following ": 50,
#         "Type Of Page ": "🚩",
#         "Bio ": "tuli..🧿🖤\n__Life is a book with every chapter\nteaching something new."
#     },
#     {
#         "Username": "khushi_bishal_",
#         "Name": "khushi_bishal_♓️",
#         "No of Post": 290,
#         "No of Followers": 1049,
#         "No of Following ": 452,
#         "Type Of Page ": "🌸 Be real. Stay kind. Grow strong.",
#         "Bio ": "feb 19 ♓️\n27/05 🌻"
#     },
#     {
#         "Username": "jain_underground",
#         "Name": "Jain Underground",
#         "No of Post": 53,
#         "No of Followers": 383,
#         "No of Following ": 474,
#         "Type Of Page ": "The unofficial voice of Jain 💬",
#         "Bio ": "Confessions. Chaos. Red flags. Secrets\nWelcome to the Underground 🔥"
#     },
#     {
#         "Username": "m_living_dead",
#         "Name": "shreet panda...",
#         "No of Post": 22,
#         "No of Followers": 449,
#         "No of Following ": 742,
#         "Type Of Page ": "Artist",
#         "Bio ": "life is all about moving onnn...\nSatisfied for now... More to come!"
#     },
#     {
#         "Username": "_nxthrx_.04_",
#         "Name": "ℕ𝕖𝕥𝕙𝕣𝕒🖤",
#         "No of Post": 0,
#         "No of Followers": 918,
#         "No of Following ": 1194,
#         "Type Of Page ": "~JU'29🎓",
#         "Bio ": ".\n.\n.\n.\n~@_.poovi._08_ 🤍🧿\n~close your eyes face the sun smile🤍☄️🎀"
#     },
#     {
#         "Username": "jain_confession77",
#         "Name": "Jain College Jayanagar confession",
#         "No of Post": 55,
#         "No of Followers": 1111,
#         "No of Following ": 911,
#         "Type Of Page ": "“GPA? Nah. Gossip Per Annum — we got that covered.”😮‍💨☠️",
#         "Bio ": "confess.ngl.link/confessyourheartout18489"
#     },
#     {
#         "Username": "coder4gamer4passion",
#         "Name": "ʞɘʜꙅiʜdA",
#         "No of Post": 1,
#         "No of Followers": 68,
#         "No of Following ": 203,
#         "Type Of Page ": "꧁༒♛𝔄𝔟𝔥𝔦𝔰𝔥𝔢𝔨♛༒꧂",
#         "Bio ": ""
#     },
#     {
#         "Username": "yuvr_ajsingh._.0019",
#         "Name": "🖤Yuvraj Singh🩶",
#         "No of Post": 17,
#         "No of Followers": 722,
#         "No of Following ": 381,
#         "Type Of Page ": "Eunoia 🌸",
#         "Bio ": ""
#     },
#     {
#         "Username": "alok4537singh",
#         "Name": "Alok kumar singh",
#         "No of Post": 1,
#         "No of Followers": 122,
#         "No of Following ": 185,
#         "Type Of Page ": "Zindagi Gulzar Hai",
#         "Bio ": "JU || Blr"
#     },
#     {
#         "Username": "dearnitya",
#         "Name": "nitya ꩜x",
#         "No of Post": 0,
#         "No of Followers": 815,
#         "No of Following ": 700,
#         "Type Of Page ": "୨୧ 🌺",
#         "Bio ": "@radvxz\npin.it/5M4RkFNxG"
#     },
#     {
#         "Username": "amanchand_20",
#         "Name": "Aman Chand",
#         "No of Post": 1,
#         "No of Followers": 114,
#         "No of Following ": 108,
#         "Type Of Page ": "Unknown",
#         "Bio ": ""
#     },
#     {
#         "Username": "__anmol_11",
#         "Name": "Anmol Regmi",
#         "No of Post": 20,
#         "No of Followers": 343,
#         "No of Following ": 245,
#         "Type Of Page ": "Don't follow me... Cause I don't know where I am going😎💀",
#         "Bio ": ""
#     },
#     {
#         "Username": "dsclassof29",
#         "Name": "Class of 29",
#         "No of Post": 2,
#         "No of Followers": 38,
#         "No of Following ": 39,
#         "Type Of Page ": "Polaroids today, flames tomorrow",
#         "Bio ": "#29crew"
#     },
#     {
#         "Username": "jwaline_",
#         "Name": "jwaline",
#         "No of Post": 21,
#         "No of Followers": 4138,
#         "No of Following ": 1762,
#         "Type Of Page ": "Actor",
#         "Bio ": "KL 📍Bgrl\nDo something new.\nPhase of expansion."
#     },
#     {
#         "Username": "souravvv_20",
#         "Name": "𝙎𝙊𝙐𝙍𝘼𝙑",
#         "No of Post": 1,
#         "No of Followers": 331,
#         "No of Following ": 236,
#         "Type Of Page ": "📍Bengaluru",
#         "Bio ": ""
#     },
#     {
#         "Username": "_aromalsuresh_",
#         "Name": "aro",
#         "No of Post": 0,
#         "No of Followers": 1637,
#         "No of Following ": 1539,
#         "Type Of Page ": "Patience.",
#         "Bio ": ""
#     },
#     {
#         "Username": "_.akshay.ps._",
#         "Name": "aks_hay_89",
#         "No of Post": 3,
#         "No of Followers": 1218,
#         "No of Following ": 977,
#         "Type Of Page ": "Personal blog",
#         "Bio ": "ernakulam 📍bangalore"
#     },
#     {
#         "Username": "senthil7379",
#         "Name": "senthil kumar",
#         "No of Post": 4,
#         "No of Followers": 41,
#         "No of Following ": 73,
#         "Type Of Page ": "Unknown",
#         "Bio ": ""
#     },
#     {
#         "Username": "aditiya_sahrawat09",
#         "Name": "Aditiya",
#         "No of Post": 0,
#         "No of Followers": 247,
#         "No of Following ": 324,
#         "Type Of Page ": "yearning",
#         "Bio ": ""
#     },
#     {
#         "Username": "adithyaa_31",
#         "Name": "Adiii🖤",
#         "No of Post": 4,
#         "No of Followers": 906,
#         "No of Following ": 932,
#         "Type Of Page ": "\"𝓡𝓪𝓭𝓱𝓮 𝓴𝓻𝓲𝓼𝓱𝓷𝓪\"",
#         "Bio ": "𝑯𝒂𝒍𝒇 𝒄𝒐𝒇𝒇𝒆𝒆, 𝒉𝒂𝒍𝒇 𝒂𝒎𝒃𝒊𝒕𝒊𝒐𝒏"
#     },
#     {
#         "Username": "4ppl_ju1ce",
#         "Name": "evicka.png",
#         "No of Post": 15,
#         "No of Followers": 269,
#         "No of Following ": 1026,
#         "Type Of Page ": "🤍🦌🐇🩰",
#         "Bio ": "@h4n1kk\n.\n.\n.\n.\n.\n.\n."
#     },
#     {
#         "Username": "ansh_sharaff",
#         "Name": "Ānsh Sharaff",
#         "No of Post": 33,
#         "No of Followers": 139,
#         "No of Following ": 194,
#         "Type Of Page ": "radhe radhe❤️❤️",
#         "Bio ": ""
#     },
#     {
#         "Username": "adhikarigaurabh",
#         "Name": "G A U R A B H",
#         "No of Post": 7,
#         "No of Followers": 429,
#         "No of Following ": 376,
#         "Type Of Page ": "Euphoric",
#         "Bio ": ""
#     },
#     {
#         "Username": "raunak_sarraf__",
#         "Name": "Raunak sarraf",
#         "No of Post": 0,
#         "No of Followers": 193,
#         "No of Following ": 220,
#         "Type Of Page ": "JU' 29(maybe 30, worst case scenario 31)",
#         "Bio ": "So Far, So good🍃"
#     },
#     {
#         "Username": "hareshhhh.h",
#         "Name": "𝙃𝘼𝙍𝙀𝙎𝙃",
#         "No of Post": 5,
#         "No of Followers": 1016,
#         "No of Following ": 1034,
#         "Type Of Page ": "just documenting the life 📽",
#         "Bio ": ""
#     },
#     {
#         "Username": "wishallllllltejas",
#         "Name": "Vishal Tejas",
#         "No of Post": 5,
#         "No of Followers": 326,
#         "No of Following ": 309,
#         "Type Of Page ": "Dolce far niente",
#         "Bio ": "@the.cforge Content Creator 😎"
#     },
#     {
#         "Username": "pranish_k7",
#         "Name": "Pranish Karki",
#         "No of Post": 0,
#         "No of Followers": 179,
#         "No of Following ": 226,
#         "Type Of Page ": "Just try it",
#         "Bio ": ""
#     },
#     {
#         "Username": "kps.alf",
#         "Name": "Ken",
#         "No of Post": 0,
#         "No of Followers": 130,
#         "No of Following ": 149,
#         "Type Of Page ": "Unknown",
#         "Bio ": ""
#     },
#     null,
#     null,
#     null,
#     null,
#     null,
#     null,
#     null,
#     null,
#     null
# ]
